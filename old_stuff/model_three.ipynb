# %%
import random
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from scipy.spatial import Delaunay

# %%
n = 20 # number of nodes I want in graph
rand_seed = 50 # 13, 47, 50

# %%
random.seed(rand_seed) # Must be in the same code chunk as when I am doing the randomness

G = nx.Graph()
x_axis = {}
y_axis = {}
for i in range(0, n):
    x_axis[i] = round(random.random(), 3)
    y_axis[i] = round(random.random(), 3)
    G.add_node(i)

nx.set_node_attributes(G, x_axis, name='x_axis')
nx.set_node_attributes(G, y_axis, name='y_axis')

# %%
# Create a list of node positions
points = np.array([[float(G.nodes()[v]['x_axis']), float(G.nodes()[v]['y_axis'])] for v in G.nodes()])

# %%
tri = Delaunay(points)

# %%
plt.triplot(points[:,0], points[:,1], tri.simplices)
plt.plot(points[:,0], points[:,1], 'o')
plt.title(f'{n} vertices at random seed {rand_seed}')
#plt.savefig(f'/Users/annef/Coding_Data_Projects/Thesis/senior-thesis/imgs/model_three/{n}-{rand_seed}.png')
# Out:
# Text(0.5, 1.0, '20 vertices at random seed 50')
